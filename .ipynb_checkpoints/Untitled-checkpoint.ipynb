# %% [markdown]
# # **CREAR DATAFRAME**

# %%
import pandas as pd
import glob
pd.set_option('display.max_columns', None) #no funcionó
csv_files = glob.glob("DATA/*Friday*.csv") 

df_combinado = pd.DataFrame()

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    df_combinado = pd.concat([df_combinado,df])

# %% [markdown]
# # **LIMPIEZA**

# %%
df_combinado.columns = df_combinado.columns.str.strip()
#df_combinado = df_combinado.rename(columns = {' Label':'Tipo'}) tiene un espacio
df_combinado

import numpy as py

df_combinado.dtypes
# Out:
# Destination Port                 int64
# Flow Duration                    int64
# Total Fwd Packets                int64
# Total Backward Packets           int64
# Total Length of Fwd Packets      int64
#                                 ...
# Idle Mean                      float64
# Idle Std                       float64
# Idle Max                         int64
# Idle Min                         int64
# Label                           object
# Length: 79, dtype: object

# %% [markdown]
# # **TOMAR DATOS**

# %%
# ver que no todas las label sean benignas, ver records con label no benign
benigno = df_combinado.loc[df_combinado["Label"] != 'BENIGN']
benigno
# Out:
#         Destination Port  Flow Duration  Total Fwd Packets  \
# 18883                 80        1293792                  3
# 18884                 80        4421382                  4
# 18885                 80        1083538                  3
# 18886                 80       80034360                  8
# 18887                 80         642654                  3
# ...                  ...            ...                ...
# 190999              8080        1030558                  3
# 191000              8080        1008819                  3
# 191001              8080        1032755                  3
# 191015              8080        1045087                  3
# 191022              8080         997161                  3
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# 18883                        7                           26
# 18884                        0                           24
# 18885                        6                           26
# 18886                        4                           56
# 18887                        6                           26
# ...                        ...                          ...
# 190999                       3                            0
# 191000                       3                            0
# 191001                       3                            0
# 191015                       3                            0
# 191022                       3                            0
#
#         Total Length of Bwd Packets  Fwd Packet Length Max  \
# 18883                         11607                     20
# 18884                             0                      6
# 18885                         11601                     20
# 18886                         11601                     20
# 18887                         11607                     20
# ...                             ...                    ...
# 190999                           18                      0
# 191000                           18                      0
# 191001                           18                      0
# 191015                           18                      0
# 191022                           18                      0
#
#         Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# 18883                       0                8.666667              10.263203
# 18884                       6                6.000000               0.000000
# 18885                       0                8.666667              10.263203
# 18886                       0                7.000000               5.656854
# 18887                       0                8.666667              10.263203
# ...                       ...                     ...                    ...
# 190999                      0                0.000000               0.000000
# 191000                      0                0.000000               0.000000
# 191001                      0                0.000000               0.000000
# 191015                      0                0.000000               0.000000
# 191022                      0                0.000000               0.000000
#
#         Bwd Packet Length Max  Bwd Packet Length Min  Bwd Packet Length Mean  \
# 18883                    5840                      0             1658.142857
# 18884                       0                      0                0.000000
# 18885                    4380                      0             1933.500000
# 18886                    8760                      0             2900.250000
# 18887                    5840                      0             1934.500000
# ...                       ...                    ...                     ...
# 190999                      6                      6                6.000000
# 191000                      6                      6                6.000000
# 191001                      6                      6                6.000000
# 191015                      6                      6                6.000000
# 191022                      6                      6                6.000000
#
#         Bwd Packet Length Std  Flow Bytes/s  Flow Packets/s  Flow IAT Mean  \
# 18883             2137.297080   8991.398927        7.729218   1.437547e+05
# 18884                0.000000      5.428167        0.904695   1.473794e+06
# 18885             1757.789948  10730.588130        8.306123   1.354422e+05
# 18886             4128.319301    145.649943        0.149936   7.275851e+06
# 18887             2538.919278  18101.497850       14.004425   8.033175e+04
# ...                       ...           ...             ...            ...
# 190999               0.000000     17.466266        5.822089   2.061116e+05
# 191000               0.000000     17.842646        5.947549   2.017638e+05
# 191001               0.000000     17.429110        5.809703   2.065510e+05
# 191015               0.000000     17.223446        5.741149   2.090174e+05
# 191022               0.000000     18.051247        6.017082   1.994322e+05
#
#         Flow IAT Std  Flow IAT Max  Flow IAT Min  Fwd IAT Total  Fwd IAT Mean  \
# 18883   4.308658e+05       1292730             2            747         373.5
# 18884   2.552043e+06       4420639           340        4421382     1473794.0
# 18885   3.777253e+05       1070206            41          12982        6491.0
# 18886   2.110000e+07      70600000             6       78700000    11200000.0
# 18887   2.268247e+05        641694             3            801         400.5
# ...              ...           ...           ...            ...           ...
# 190999  2.813539e+05        514938           498        1029824      514912.0
# 191000  2.756001e+05        508667           408        1008411      504205.5
# 191001  2.819193e+05        518164           616        1032034      516017.0
# 191015  2.855245e+05        528391           481        1044606      522303.0
# 191022  2.723464e+05        498649           499         996662      498331.0
#
#          Fwd IAT Std  Fwd IAT Max  Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  \
# 18883   5.239661e+02          744            3        1293746   215624.3333
# 18884   2.552043e+06      4420639          340              0        0.0000
# 18885   8.165669e+03        12265          717        1083407   216681.4000
# 18886   2.630000e+07     70600000          247        1354806   451602.0000
# 18887   5.409367e+02          783           18         642493   128498.6000
# ...              ...          ...          ...            ...           ...
# 190999  1.009748e+03       515626       514198        1030060   515030.0000
# 191000  7.054804e+03       509194       499217        1008292   504146.0000
# 191001  3.907472e+03       518780       513254        1032078   516039.0000
# 191015  9.468160e+03       528998       515608        1044480   522240.0000
# 191022  1.234608e+03       499204       497458         996598   498299.0000
#
#           Bwd IAT Std  Bwd IAT Max  Bwd IAT Min  Fwd PSH Flags  Bwd PSH Flags  \
# 18883   527671.934800      1292730            2              0              0
# 18884        0.000000            0            0              0              0
# 18885   477167.097700      1070206           41              0              0
# 18886   777575.259200      1349464          190              0              0
# 18887   286885.116900       641694            3              0              0
# ...               ...          ...          ...            ...            ...
# 190999     907.925107       515672       514388              0              0
# 191000    7237.945012       509264       499028              0              0
# 191001    4024.851799       518885       513193              0              0
# 191015    9400.277549       528887       515593              0              0
# 191022    1200.667314       499148       497450              0              0
#
#         Fwd URG Flags  Bwd URG Flags  Fwd Header Length  Bwd Header Length  \
# 18883               0              0                 72                152
# 18884               0              0                 80                  0
# 18885               0              0                 72                132
# 18886               0              0                172                 92
# 18887               0              0                 72                132
# ...               ...            ...                ...                ...
# 190999              0              0                 92                 60
# 191000              0              0                 92                 60
# 191001              0              0                 92                 60
# 191015              0              0                 92                 60
# 191022              0              0                 92                 60
#
#         Fwd Packets/s  Bwd Packets/s  Min Packet Length  Max Packet Length  \
# 18883        2.318765       5.410452                  0               5840
# 18884        0.904695       0.000000                  6                  6
# 18885        2.768708       5.537415                  0               4380
# 18886        0.099957       0.049979                  0               8760
# 18887        4.668142       9.336284                  0               5840
# ...               ...            ...                ...                ...
# 190999       2.911044       2.911044                  0                  6
# 191000       2.973774       2.973774                  0                  6
# 191001       2.904852       2.904852                  0                  6
# 191015       2.870574       2.870574                  0                  6
# 191022       3.008541       3.008541                  0                  6
#
#         Packet Length Mean  Packet Length Std  Packet Length Variance  \
# 18883          1057.545455        1853.437529            3.435231e+06
# 18884             6.000000           0.000000            0.000000e+00
# 18885          1162.700000        1645.241762            2.706820e+06
# 18886           897.153846        2488.507044            6.192667e+06
# 18887          1163.300000        2138.329153            4.572452e+06
# ...                    ...                ...                     ...
# 190999            2.571429           3.207135            1.028571e+01
# 191000            2.571429           3.207135            1.028571e+01
# 191001            2.571429           3.207135            1.028571e+01
# 191015            2.571429           3.207135            1.028571e+01
# 191022            2.571429           3.207135            1.028571e+01
#
#         FIN Flag Count  SYN Flag Count  RST Flag Count  PSH Flag Count  \
# 18883                0               0               0               1
# 18884                0               0               0               0
# 18885                0               0               0               1
# 18886                0               0               0               0
# 18887                0               0               0               1
# ...                ...             ...             ...             ...
# 190999               0               0               0               1
# 191000               0               0               0               1
# 191001               0               0               0               1
# 191015               0               0               0               1
# 191022               0               0               0               1
#
#         ACK Flag Count  URG Flag Count  CWE Flag Count  ECE Flag Count  \
# 18883                0               0               0               0
# 18884                1               0               0               0
# 18885                0               0               0               0
# 18886                1               0               0               0
# 18887                0               0               0               0
# ...                ...             ...             ...             ...
# 190999               0               0               0               0
# 191000               0               0               0               0
# 191001               0               0               0               0
# 191015               0               0               0               0
# 191022               0               0               0               0
#
#         Down/Up Ratio  Average Packet Size  Avg Fwd Segment Size  \
# 18883               2          1163.300000              8.666667
# 18884               0             7.500000              6.000000
# 18885               2          1291.888889              8.666667
# 18886               0           971.916667              7.000000
# 18887               2          1292.555556              8.666667
# ...               ...                  ...                   ...
# 190999              1             3.000000              0.000000
# 191000              1             3.000000              0.000000
# 191001              1             3.000000              0.000000
# 191015              1             3.000000              0.000000
# 191022              1             3.000000              0.000000
#
#         Avg Bwd Segment Size  Fwd Header Length.1  Fwd Avg Bytes/Bulk  \
# 18883            1658.142857                   72                   0
# 18884               0.000000                   80                   0
# 18885            1933.500000                   72                   0
# 18886            2900.250000                  172                   0
# 18887            1934.500000                   72                   0
# ...                      ...                  ...                 ...
# 190999              6.000000                   92                   0
# 191000              6.000000                   92                   0
# 191001              6.000000                   92                   0
# 191015              6.000000                   92                   0
# 191022              6.000000                   92                   0
#
#         Fwd Avg Packets/Bulk  Fwd Avg Bulk Rate  Bwd Avg Bytes/Bulk  \
# 18883                      0                  0                   0
# 18884                      0                  0                   0
# 18885                      0                  0                   0
# 18886                      0                  0                   0
# 18887                      0                  0                   0
# ...                      ...                ...                 ...
# 190999                     0                  0                   0
# 191000                     0                  0                   0
# 191001                     0                  0                   0
# 191015                     0                  0                   0
# 191022                     0                  0                   0
#
#         Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  Subflow Fwd Packets  \
# 18883                      0                  0                    3
# 18884                      0                  0                    4
# 18885                      0                  0                    3
# 18886                      0                  0                    8
# 18887                      0                  0                    3
# ...                      ...                ...                  ...
# 190999                     0                  0                    3
# 191000                     0                  0                    3
# 191001                     0                  0                    3
# 191015                     0                  0                    3
# 191022                     0                  0                    3
#
#         Subflow Fwd Bytes  Subflow Bwd Packets  Subflow Bwd Bytes  \
# 18883                  26                    7              11607
# 18884                  24                    0                  0
# 18885                  26                    6              11601
# 18886                  56                    4              11601
# 18887                  26                    6              11607
# ...                   ...                  ...                ...
# 190999                  0                    3                 18
# 191000                  0                    3                 18
# 191001                  0                    3                 18
# 191015                  0                    3                 18
# 191022                  0                    3                 18
#
#         Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 18883                     8192                      229                 2
# 18884                      256                       -1                 3
# 18885                     8192                      229                 2
# 18886                      256                      229                 6
# 18887                     8192                      229                 2
# ...                        ...                      ...               ...
# 190999                    8192                        0                 0
# 191000                    8192                        0                 0
# 191001                    8192                        0                 0
# 191015                    8192                        0                 0
# 191022                    8192                        0                 0
#
#         min_seg_size_forward  Active Mean  Active Std  Active Max  Active Min  \
# 18883                     20          0.0         0.0           0           0
# 18884                     20          0.0         0.0           0           0
# 18885                     20          0.0         0.0           0           0
# 18886                     20        939.0         0.0         939         939
# 18887                     20          0.0         0.0           0           0
# ...                      ...          ...         ...         ...         ...
# 190999                    28          0.0         0.0           0           0
# 191000                    28          0.0         0.0           0           0
# 191001                    28          0.0         0.0           0           0
# 191015                    28          0.0         0.0           0           0
# 191022                    28          0.0         0.0           0           0
#
#          Idle Mean    Idle Std  Idle Max  Idle Min Label
# 18883          0.0         0.0         0         0  DDoS
# 18884          0.0         0.0         0         0  DDoS
# 18885          0.0         0.0         0         0  DDoS
# 18886   39300000.0  44200000.0  70600000   8072664  DDoS
# 18887          0.0         0.0         0         0  DDoS
# ...            ...         ...       ...       ...   ...
# 190999         0.0         0.0         0         0   Bot
# 191000         0.0         0.0         0         0   Bot
# 191001         0.0         0.0         0         0   Bot
# 191015         0.0         0.0         0         0   Bot
# 191022         0.0         0.0         0         0   Bot
#
# [288923 rows x 79 columns]

# %% [markdown]
# # **INPUT & OUTPUT SETS**

# %%
from sklearn.tree import DecisionTreeClassifier

x = df_combinado.drop(columns=['Label'])
y = df_combinado['Label']

model = DecisionTreeClassifier()
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       4 y = df_combinado['Label']
#       6 model = DecisionTreeClassifier()
# ----> 7 model.fit(x,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:247, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     241 check_y_params = dict(ensure_2d=False, dtype=None)
#     242 X, y = self._validate_data(
#     243     X, y, validate_separately=(check_X_params, check_y_params)
#     244 )
#     246 missing_values_in_feature_mask = (
# --> 247     self._compute_missing_values_in_feature_mask(X)
#     248 )
#     249 if issparse(X):
#     250     X.sort_indices()
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:212, in BaseDecisionTree._compute_missing_values_in_feature_mask(self, X)
#     208     overall_sum = np.sum(X)
#     210 if not np.isfinite(overall_sum):
#     211     # Raise a ValueError in case of the presence of an infinite element.
# --> 212     _assert_all_finite_element_wise(X, xp=np, allow_nan=True, **common_kwargs)
#     214 # If the sum is not nan, then there are no missing values
#     215 if not np.isnan(overall_sum):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float32').
